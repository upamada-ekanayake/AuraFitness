# %% [markdown]
# # 05 Export Validation
#
# ## Objective
#
# Check that exported JSON files are clean, valid, and app-friendly before React integration.
#
# ## Dataset Source
#
# Reference the real datasets and processed files used to create exports.
#
# ## License/Usage Note
#
# Confirm exports are allowed by the source dataset license.

# %% [markdown]
# ## Required Validation
#
# 1. Load exported JSON files
# 2. Check required keys
# 3. Check missing values
# 4. Check app-friendly shape
# 5. Confirm no fake training data
# 6. React integration decision
