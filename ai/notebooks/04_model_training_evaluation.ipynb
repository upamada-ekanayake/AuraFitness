# %% [markdown]
# # 04 Model Training Evaluation
#
# ## Objective
#
# Train simple ML models only after real dataset exploration and cleaning.
#
# ## Dataset Source
#
# List the real dataset and cleaned processed input file.
#
# ## License/Usage Note
#
# Confirm the dataset license supports model training and app usage.

# %% [markdown]
# ## Required Model Workflow
#
# 1. Train/test split
# 2. Baseline model
# 3. Accuracy or error metrics
# 4. Confusion matrix if classification
# 5. MAE/RMSE if regression
# 6. Feature importance if possible
# 7. Final model decision
# 8. Save model with joblib
